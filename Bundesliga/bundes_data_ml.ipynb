# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import plotly.express as px

# %%
bundes_data=pd.read_csv("BLiga_2015_2026_Data.csv")
team_occurence=bundes_data['squad'].value_counts()
print(team_occurence)
# Out:
# squad
# Bayern Munich     11
# Dortmund          11
# Leverkusen        11
# Gladbach          11
# Mainz 05          11
# Wolfsburg         11
# Augsburg          11
# Hoffenheim        11
# Eint Frankfurt    11
# Werder Bremen     10
# RB Leipzig        10
# Freiburg          10
# Köln               9
# Stuttgart          9
# Hertha BSC         8
# Union Berlin       7
# Schalke 04         7
# Hamburger SV       4
# Bochum             4
# Darmstadt 98       3
# Heidenheim         3
# Hannover 96        3
# Ingolstadt 04      2
# Düsseldorf         2
# St. Pauli          2
# Arminia            2
# Nürnberg           1
# Paderborn 07       1
# Greuther Fürth     1
# Holstein Kiel      1
# Name: count, dtype: int64

# %%
bundes_data['squad'].groupby(bundes_data['rk']).value_counts().head(10)
# Out:
# rk  squad
# 1   Bayern Munich    10
#     Leverkusen        1
# 2   Dortmund          5
#     RB Leipzig        3
#     Leverkusen        1
#     Schalke 04        1
#     Stuttgart         1
# 3   Dortmund          3
#     RB Leipzig        3
#     Leverkusen        2
# Name: count, dtype: int64

# %%
ranking_counts = bundes_data['squad'].groupby(bundes_data['rk']).value_counts().reset_index(name='count')
ranking_counts = ranking_counts[ranking_counts['rk'].isin([1,2,3,4])]

fig = px.bar(ranking_counts, x='squad', y='count', color='rk',
             barmode='group',
             title='Top 4 Finishes by Team and Rank (Last 10 Years)',
             labels={'squad': 'Team', 'count': 'Finish Count', 'rk': 'Rank'})

fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.show()

# %%
league_winners_bundes = bundes_data[bundes_data["rk"] == 1][["season", "squad", "pts", "pts/mp", "gd"]].sort_values("season")
print(league_winners_bundes)
# Out:
#      season           squad  pts  pts/mp  gd
# 0      2015   Bayern Munich   88    2.59  63
# 18     2016   Bayern Munich   82    2.41  67
# 36     2017   Bayern Munich   84    2.47  64
# 54     2018   Bayern Munich   78    2.29  56
# 72     2019   Bayern Munich   82    2.41  68
# 90     2020   Bayern Munich   78    2.29  55
# 108    2021   Bayern Munich   77    2.26  60
# 126    2022   Bayern Munich   71    2.09  54
# 144    2023      Leverkusen   90    2.65  65
# 162    2024   Bayern Munich   82    2.41  67
# 180    2025   Bayern Munich   38    2.71  40

# %%
league_winners_bundes_last_10 = bundes_data[(bundes_data["rk"] == 1) & (bundes_data["season"] < 2024)]
avg_pts_mp_winners = league_winners_bundes_last_10["pts/mp"].mean().__round__(2)
print(avg_pts_mp_winners)
# Out:
# 2.38

# %%
bundes_data['league_winner'] = (bundes_data['rk'] == 1).astype(int)

champions=bundes_data[bundes_data['league_winner'] == 1]
print(champions)
# Out:
#      rk           squad  mp   w  d  l   gf  ga  gd  pts  ...  \
# 0     1   Bayern Munich  34  28  4  2   80  17  63   88  ...
# 18    1   Bayern Munich  34  25  7  2   89  22  67   82  ...
# 36    1   Bayern Munich  34  27  3  4   92  28  64   84  ...
# 54    1   Bayern Munich  34  24  6  4   88  32  56   78  ...
# 72    1   Bayern Munich  34  26  4  4  100  32  68   82  ...
# 90    1   Bayern Munich  34  24  6  4   99  44  55   78  ...
# 108   1   Bayern Munich  34  24  5  5   97  37  60   77  ...
# 126   1   Bayern Munich  34  21  8  5   92  38  54   71  ...
# 144   1      Leverkusen  34  28  6  0   89  24  65   90  ...
# 162   1   Bayern Munich  34  25  7  2   99  32  67   82  ...
# 180   1   Bayern Munich  14  12  2  0   51  11  40   38  ...
#
#              top_team_scorer      goalkeeper  \
# 0    Robert Lewandowski - 30    Manuel Neuer
# 18   Robert Lewandowski - 30    Manuel Neuer
# 36   Robert Lewandowski - 29    Sven Ulreich
# 54   Robert Lewandowski - 22    Manuel Neuer
# 72   Robert Lewandowski - 34    Manuel Neuer
# 90   Robert Lewandowski - 41    Manuel Neuer
# 108  Robert Lewandowski - 35    Manuel Neuer
# 126        Serge Gnabry - 14     Yann Sommer
# 144     Victor Boniface - 14  Lukáš Hrádecký
# 162          Harry Kane - 26    Manuel Neuer
# 180          Harry Kane - 18    Manuel Neuer
#
#                                     notes season    xg   xga   xgd  xgd/90  \
# 0    → Champions League via league finish   2015   NaN   NaN   NaN     NaN
# 18   → Champions League via league finish   2016   NaN   NaN   NaN     NaN
# 36   → Champions League via league finish   2017  75.8  31.7  44.1    1.30
# 54   → Champions League via league finish   2018  85.6  27.2  58.4    1.72
# 72   → Champions League via league finish   2019  89.5  37.9  51.6    1.52
# 90   → Champions League via league finish   2020  75.9  40.2  35.8    1.05
# 108  → Champions League via league finish   2021  89.0  36.3  52.7    1.55
# 126  → Champions League via league finish   2022  75.0  37.1  37.8    1.11
# 144  → Champions League via league finish   2023  73.6  29.9  43.7    1.29
# 162  → Champions League via league finish   2024  81.7  25.5  56.2    1.65
# 180                                   NaN   2025  39.4   9.4  30.0    2.14
#
#         last_5  league_winner
# 0          NaN              1
# 18         NaN              1
# 36         NaN              1
# 54         NaN              1
# 72         NaN              1
# 90         NaN              1
# 108        NaN              1
# 126        NaN              1
# 144        NaN              1
# 162        NaN              1
# 180  D W W W D              1
#
# [11 rows x 22 columns]

# %%
mean_pts_mp_champions = champions["pts/mp"].mean().__round__(2)

print(mean_pts_mp_champions)
# Out:
# 2.42

# %% [markdown]
# # Machine Learning-Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier  
from sklearn.preprocessing import StandardScaler     
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, log_loss  
from sklearn.model_selection import cross_val_score  
import pandas as pd                                  
import numpy as np

# %%
bundes_data["games_left"] = 38 - bundes_data["mp"]
bundes_data["projected_pts"] = bundes_data["pts"] + bundes_data["games_left"] * bundes_data["pts/mp"]
bundes_data["is_champion"] = (bundes_data["rk"] == 1).astype(int)

# %%
features = ["pts/mp", "gd", "w", "l", "projected_pts"]

df_train = bundes_data[bundes_data["season"] < 2025]

df_test = bundes_data[bundes_data["season"] == 2025].copy()

X_train = df_train[features]
y_train = df_train["is_champion"]
X_test = df_test[features]

# %%
model = RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
train_preds = model.predict(X_train)
train_probs = model.predict_proba(X_train)[:, 1]

# %%
accuracy = accuracy_score(y_train, train_preds)

roc_auc = roc_auc_score(y_train, train_probs)

logloss = log_loss(y_train, train_probs)

print(accuracy)
print(roc_auc)
print(logloss)

print("\nClassification Report:")
print(classification_report(y_train, train_preds))

print("Confusion Matrix:")
print(confusion_matrix(y_train, train_preds))
# Out:
# 1.0
# 1.0
# 0.005427852582274104
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       170
#            1       1.00      1.00      1.00        10
#
#     accuracy                           1.00       180
#    macro avg       1.00      1.00      1.00       180
# weighted avg       1.00      1.00      1.00       180
#
# Confusion Matrix:
# [[170   0]
#  [  0  10]]

# %%
df_test["win_probability"] = model.predict_proba(X_test)[:, 1]

# %%
df_test.head()
# Out:
#      rk           squad  mp   w  d  l  gf  ga  gd  pts  ...    xg   xga   xgd  \
# 180   1   Bayern Munich  14  12  2  0  51  11  40   38  ...  39.4   9.4  30.0
# 181   2      RB Leipzig  14   9  2  3  29  16  13   29  ...  26.1  18.0   8.1
# 182   3        Dortmund  14   8  5  1  24  12  12   29  ...  21.6  14.4   7.2
# 183   4      Leverkusen  14   8  2  4  30  19  11   26  ...  24.3  16.0   8.3
# 184   5      Hoffenheim  14   8  2  4  29  20   9   26  ...  22.4  21.4   1.0
#
#     xgd/90     last_5  league_winner  games_left  projected_pts  is_champion  \
# 180   2.14  D W W W D              1          24         103.04            1
# 181   0.58  L W D W L              0          24          78.68            0
# 182   0.52  D D W W D              0          24          78.68            0
# 183   0.59  W W L L W              0          24          70.64            0
# 184   0.07  W D W L W              0          24          70.64            0
#
#      win_probability
# 180            0.295
# 181            0.120
# 182            0.120
# 183            0.005
# 184            0.005
#
# [5 rows x 26 columns]

# %%
df_test["win_probability (%)"] = df_test["win_probability"] / df_test["win_probability"].sum() * 100
df_test["win_probability (%)"] = df_test["win_probability (%)"].round(3)

# %%
df_test = df_test.sort_values("projected_pts", ascending=False)
print("\nChampionship Win Probabilities (2025):")
df_test[["squad", "pts", "projected_pts", "pts/mp", "gd", "games_left", "win_probability (%)"]]
# Out:
# Championship Win Probabilities (2025):
#                squad  pts  projected_pts  pts/mp  gd  games_left  \
# 180    Bayern Munich   38         103.04    2.71  40          24
# 181       RB Leipzig   29          78.68    2.07  13          24
# 182         Dortmund   29          78.68    2.07  12          24
# 183       Leverkusen   26          70.64    1.86  11          24
# 184       Hoffenheim   26          70.64    1.86   9          24
# 185        Stuttgart   25          67.96    1.79   3          24
# 186   Eint Frankfurt   24          65.04    1.71   0          24
# 187     Union Berlin   18          48.96    1.29  -4          24
# 188         Freiburg   17          46.04    1.21  -2          24
# 189             Köln   16          43.36    1.14  -1          24
# 190         Gladbach   16          43.36    1.14  -4          24
# 191    Werder Bremen   16          43.36    1.14 -10          24
# 192        Wolfsburg   15          40.68    1.07  -4          24
# 193     Hamburger SV   15          40.68    1.07  -9          24
# 194         Augsburg   13          35.32    0.93 -11          24
# 195        St. Pauli   11          29.96    0.79 -13          24
# 196       Heidenheim   11          29.96    0.79 -17          24
# 197         Mainz 05    7          19.00    0.50 -13          24
#
#      win_probability (%)
# 180               50.000
# 181               20.339
# 182               20.339
# 183                0.847
# 184                0.847
# 185                3.390
# 186                0.847
# 187                0.000
# 188                3.390
# 189                0.000
# 190                0.000
# 191                0.000
# 192                0.000
# 193                0.000
# 194                0.000
# 195                0.000
# 196                0.000
# 197                0.000

# %%
import plotly.express as px

df_test_sorted = df_test.sort_values("projected_pts", ascending=False)


fig = px.bar(
    df_test_sorted,
    x="squad",
    y="win_probability (%)",
    color_discrete_sequence=["#1f77b4"],
    title="Championship Win Probabilities (2025 Season)",
    labels={"squad": "Team", "win_probability (%)": "Win Probability (%)"},
    template="plotly_white"
)

fig.update_layout(
    xaxis_title="Team",
    yaxis_title="Win Probability (%)",
    xaxis_tickangle=-45,
    bargap=0.3,
    title_x=0.5
)

fig.show()
